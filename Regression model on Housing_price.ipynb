# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("house_prices.csv")

# %%
df1=df

# %%
df1.head()
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  GarageArea  WoodDeckSF  \
# 0       196.0         706           0        150  ...         548           0
# 1         0.0         978           0        284  ...         460         298
# 2       162.0         486           0        434  ...         608           0
# 3         0.0         216           0        540  ...         642           0
# 4       350.0         655           0        490  ...         836         192
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1379 non-null   float64
#  1   LotArea        1379 non-null   int64
#  2   OverallQual    1379 non-null   int64
#  3   OverallCond    1379 non-null   int64
#  4   YearBuilt      1379 non-null   int64
#  5   YearRemodAdd   1379 non-null   int64
#  6   MasVnrArea     1379 non-null   float64
#  7   BsmtFinSF1     1379 non-null   int64
#  8   BsmtFinSF2     1379 non-null   int64
#  9   BsmtUnfSF      1379 non-null   int64
#  10  TotalBsmtSF    1379 non-null   int64
#  11  1stFlrSF       1379 non-null   int64
#  12  2ndFlrSF       1379 non-null   int64
#  13  LowQualFinSF   1379 non-null   int64
#  14  GrLivArea      1379 non-null   int64
#  15  BsmtFullBath   1379 non-null   int64
#  16  BsmtHalfBath   1379 non-null   int64
#  17  FullBath       1379 non-null   int64
# ...

# %%
df1.ndim
# Out:
# 2

# %%
df1.describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1379.000000    1379.000000  1379.000000  1379.000000  1379.000000
# mean     57.766497   10695.812183     6.187092     5.577955  1972.958666
# std      35.038221   10214.702133     1.345780     1.081031    29.379883
# min       0.000000    1300.000000     2.000000     2.000000  1880.000000
# 25%      41.500000    7741.000000     5.000000     5.000000  1955.000000
# 50%      64.000000    9591.000000     6.000000     5.000000  1976.000000
# 75%      79.000000   11708.500000     7.000000     6.000000  2001.000000
# max     313.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1379.000000  1379.000000  1379.000000  1379.000000  1379.000000  ...
# mean    1985.435098   108.364757   455.578680    48.102248   570.765047  ...
# std       20.444852   184.195220   459.691379   164.324665   443.677845  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
cols=list(df1.columns)

# %%
cols
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'YrSold',
#  'SalePrice']

# %%
df1[cols]=scale.fit_transform(df1[cols])

# %%
df1
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.207668  0.033420        0.625     0.428571   0.946154
# 1        0.255591  0.038795        0.500     0.857143   0.738462
# 2        0.217252  0.046507        0.625     0.428571   0.930769
# 3        0.191693  0.038561        0.625     0.428571   0.269231
# 4        0.268371  0.060576        0.750     0.428571   0.923077
# ...           ...       ...          ...          ...        ...
# 1374     0.198083  0.030929        0.500     0.428571   0.915385
# 1375     0.271565  0.055505        0.500     0.571429   0.753846
# 1376     0.210863  0.036187        0.625     1.000000   0.469231
# 1377     0.217252  0.039342        0.375     0.571429   0.538462
# 1378     0.239617  0.040370        0.375     0.571429   0.653846
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 0         0.883333    0.122500    0.125089    0.000000   0.064212  ...
# ...

# %%
df2=df1

# %%
df2
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.207668  0.033420        0.625     0.428571   0.946154
# 1        0.255591  0.038795        0.500     0.857143   0.738462
# 2        0.217252  0.046507        0.625     0.428571   0.930769
# 3        0.191693  0.038561        0.625     0.428571   0.269231
# 4        0.268371  0.060576        0.750     0.428571   0.923077
# ...           ...       ...          ...          ...        ...
# 1374     0.198083  0.030929        0.500     0.428571   0.915385
# 1375     0.271565  0.055505        0.500     0.571429   0.753846
# 1376     0.210863  0.036187        0.625     1.000000   0.469231
# 1377     0.217252  0.039342        0.375     0.571429   0.538462
# 1378     0.239617  0.040370        0.375     0.571429   0.653846
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 0         0.883333    0.122500    0.125089    0.000000   0.064212  ...
# ...

# %%
y=df2.pop('SalePrice')

# %%
x=df2

# %%
y
# Out:
# 0       0.240644
# 1       0.203128
# 2       0.261487
# 3       0.145464
# 4       0.298308
#           ...
# 1374    0.194096
# 1375    0.242728
# 1376    0.321235
# 1377    0.148417
# 1378    0.155885
# Name: SalePrice, Length: 1379, dtype: float64

# %%
x
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.207668  0.033420        0.625     0.428571   0.946154
# 1        0.255591  0.038795        0.500     0.857143   0.738462
# 2        0.217252  0.046507        0.625     0.428571   0.930769
# 3        0.191693  0.038561        0.625     0.428571   0.269231
# 4        0.268371  0.060576        0.750     0.428571   0.923077
# ...           ...       ...          ...          ...        ...
# 1374     0.198083  0.030929        0.500     0.428571   0.915385
# 1375     0.271565  0.055505        0.500     0.571429   0.753846
# 1376     0.210863  0.036187        0.625     1.000000   0.469231
# 1377     0.217252  0.039342        0.375     0.571429   0.538462
# 1378     0.239617  0.040370        0.375     0.571429   0.653846
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 0         0.883333    0.122500    0.125089    0.000000   0.064212  ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 599      0.198083  0.053177        0.750     0.428571   0.946154
# 881      0.223642  0.036458        0.375     0.571429   0.653846
# 634      0.191693  0.038795        0.250     0.000000   0.153846
# 425      0.000000  0.037407        0.500     0.428571   0.892308
# 906      0.207668  0.033420        0.625     0.428571   0.946154
# ...           ...       ...          ...          ...        ...
# 1321     0.191693  0.027577        0.375     0.285714   0.538462
# 617      0.239617  0.040370        0.375     0.714286   0.646154
# 365      0.297125  0.037776        0.625     0.428571   0.915385
# 872      0.207668  0.041772        0.500     0.428571   0.961538
# 1087     0.287540  0.059899        0.500     0.714286   0.584615
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 599       0.900000    0.295000    0.215804    0.000000   0.128425  ...
# ...

# %%
y_test
# Out:
# 599     0.331656
# 881     0.114201
# 634     0.071821
# 425     0.234392
# 906     0.207991
#           ...
# 1321    0.142685
# 617     0.182980
# 365     0.216328
# 872     0.187135
# 1087    0.270518
# Name: SalePrice, Length: 276, dtype: float64

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
def build_model(x,y):
    x=sm.add_constant(x)
    lm=sm.OLS(y,x).fit()
    print(lm.summary())
    return lm

# %%
model1=build_model(x_train,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     145.7
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        19:21:04   Log-Likelihood:                 1791.7
# No. Observations:                1103   AIC:                            -3517.
# Df Residuals:                    1070   BIC:                            -3352.
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0956      0.013     -7.227      0.000      -0.122      -0.070
# ...

# %%
x_train1=x_train.drop(['LotFrontage','YearRemodAdd','BsmtFinSF2','BsmtUnfSF','LowQualFinSF','BsmtHalfBath','FullBath','HalfBath','Fireplaces','GarageYrBlt','GarageArea','OpenPorchSF','EnclosedPorch','3SsnPorch','PoolArea','MiscVal','YrSold'],axis=1)

# %%
col_drop=['LotFrontage','YearRemodAdd','BsmtFinSF2','BsmtUnfSF','LowQualFinSF','BsmtHalfBath','FullBath','HalfBath','Fireplaces','GarageYrBlt','GarageArea','OpenPorchSF','EnclosedPorch','3SsnPorch','PoolArea','MiscVal','YrSold']

# %%
model2=build_model(x_train1,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     274.3
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        19:30:48   Log-Likelihood:                 1785.4
# No. Observations:                1103   AIC:                            -3535.
# Df Residuals:                    1085   BIC:                            -3445.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.1014      0.012     -8.788      0.000      -0.124      -0.079
# ...

# %%
lm=LinearRegression()

# %%
x_train2=x_train1.drop(['1stFlrSF','2ndFlrSF','GrLivArea','TotalBsmtSF'],axis=1)

# %%
cols_drop2=col_drop

# %%
cols_drop2.extend(['1stFlrSF','2ndFlrSF','GrLivArea','TotalBsmtSF'])

# %%
cols_drop2
# Out:
# ['LotFrontage',
#  'YearRemodAdd',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'LowQualFinSF',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageArea',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'YrSold',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'TotalBsmtSF']

# %%
model3=build_model(x_train2,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     299.2
# Date:                Mon, 10 Apr 2023   Prob (F-statistic):               0.00
# Time:                        19:35:51   Log-Likelihood:                 1704.2
# No. Observations:                1103   AIC:                            -3380.
# Df Residuals:                    1089   BIC:                            -3310.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0969      0.012     -8.040      0.000      -0.121      -0.073
# ...

# %%
x_test1=x_test.drop(['LotFrontage',
 'YearRemodAdd',
 'BsmtFinSF2',
 'BsmtUnfSF',
 'LowQualFinSF',
 'BsmtHalfBath',
 'FullBath',
 'HalfBath',
 'Fireplaces',
 'GarageYrBlt',
 'GarageArea',
 'OpenPorchSF',
 'EnclosedPorch',
 '3SsnPorch',
 'PoolArea',
 'MiscVal',
 'YrSold',
 '1stFlrSF',
 '2ndFlrSF',
 'GrLivArea',
 'TotalBsmtSF'],axis=1)

# %%
x_test1
# Out:
#        LotArea  OverallQual  OverallCond  YearBuilt  MasVnrArea  BsmtFinSF1  \
# 599   0.053177        0.750     0.428571   0.946154    0.295000    0.215804
# 881   0.036458        0.375     0.571429   0.653846    0.000000    0.059887
# 634   0.038795        0.250     0.000000   0.153846    0.000000    0.000000
# 425   0.037407        0.500     0.428571   0.892308    0.026250    0.131467
# 906   0.033420        0.625     0.428571   0.946154    0.000000    0.123848
# ...        ...          ...          ...        ...         ...         ...
# 1321  0.027577        0.375     0.285714   0.538462    0.000000    0.031892
# 617   0.040370        0.375     0.714286   0.646154    0.000000    0.112863
# 365   0.037776        0.625     0.428571   0.915385    0.078125    0.000000
# 872   0.041772        0.500     0.428571   0.961538    0.000000    0.004961
# 1087  0.059899        0.500     0.714286   0.584615    0.000000    0.052445
#
# ...

# %%
x_test2 = sm.add_constant(x_test1)

# %%
y_pred=model3.predict(x_test2)

# %%
y
# Out:
# 0       0.240644
# 1       0.203128
# 2       0.261487
# 3       0.145464
# 4       0.298308
#           ...
# 1374    0.194096
# 1375    0.242728
# 1376    0.321235
# 1377    0.148417
# 1378    0.155885
# Name: SalePrice, Length: 1379, dtype: float64

# %%
y_pred
# Out:
# 599     0.341661
# 881     0.101474
# 634     0.059245
# 425     0.228022
# 906     0.231503
#           ...
# 1321    0.110589
# 617     0.184198
# 365     0.216174
# 872     0.177676
# 1087    0.194912
# Length: 276, dtype: float64

# %%
#calculating r2_score

# %%
from sklearn.metrics import r2_score

# %%
print("r2_score: ",r2_score(y_pred,y_test))
# Out:
# r2_score:  0.7439139762367462

# %%
#plotting graph....

# %%
fig=plt.figure()
plt.scatter(y_test,y_pred)
plt.xlabel('y_test',fontsize=5)
plt.ylabel('y_pred',fontsize=10)
# Out:
# Text(0, 0.5, 'y_pred')
